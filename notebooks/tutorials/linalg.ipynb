# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import expon

# %%
a = np.array([[1, 1, 1, 1], [-1, 0, 5, 5], [-1, 1, 0, 0], [0, 0, -1, 2]])
b = np.array([1000, 0, 0, 0])

# %%
np.linalg.solve(a, b)
# Out:
# array([454.54545455, 454.54545455,  60.60606061,  30.3030303 ])
