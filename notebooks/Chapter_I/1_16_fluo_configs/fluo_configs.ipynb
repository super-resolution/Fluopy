# %%
import matplotlib.pyplot as plt

import fluopy.miscellaneous as mi

saving_at = r"C:\Users\vie43sq\data_vincent\python_output\Chapter_I\1_16_fluo_configs"

# %%
fig, ax = plt.subplots(1, 4, figsize=(15, 4))
sky_blue = "#56B4E9"
x = [0, 1, 1, 0]
y = [0, 0, 1, 1]
labels = ["F1", "F2", "F3", "F4"]

axis = ax[0]

axis.scatter(x, y, color=sky_blue, s=100)

factors = [(-1, -1), (1, -1), (1, 1), (-1, 1)]
for xi, yi, label, (fx, fy) in zip(x, y, labels, factors):
    axis.text(
        xi + 0.08 * fx, yi + 0.08 * fy, label, fontsize=21, ha="center", va="center"
    )

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(1, 1 - offset),
    xytext=(1, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(1.05, 0.5, r"$r_1$", ha="left", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(1 - offset, 1),
    xytext=(0 + offset, 1),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(0.5, 1.08, r"$r_1$", ha="center", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(0, 1 - offset),
    xytext=(0, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(-0.05, 0.5, r"$r_1$", ha="right", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(0 + offset, 1 - offset),
    xytext=(1 - offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=21, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")

#############################################################################

x = [0, 1, 1]
y = [0, 0, 1]
labels = ["F1", "F2", "F3"]
axis = ax[1]

axis.scatter(x, y, color=sky_blue, s=100)

factors = [(-1, -1), (1, -1), (1, 1)]
for xi, yi, label, (fx, fy) in zip(x, y, labels, factors):
    axis.text(
        xi + 0.08 * fx, yi + 0.08 * fy, label, fontsize=21, ha="center", va="center"
    )
offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(1, 1 - offset),
    xytext=(1, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(1.05, 0.5, r"$r_1$", ha="left", va="center", fontsize=21)

axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=21, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")

############################################################################
x = [0, 1]
y = [0, 0]
labels = ["F1", "F2"]
axis = ax[2]
axis.scatter(x, y, color=sky_blue, s=100)

factors = [(-1, -1), (1, -1)]
for xi, yi, label, (fx, fy) in zip(x, y, labels, factors):
    axis.text(
        xi + 0.08 * fx, yi + 0.08 * fy, label, fontsize=21, ha="center", va="center"
    )

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=21)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")
############################################################################
x = [0, 1]
y = [0, 1]
labels = ["F1", "F3"]
axis = ax[3]

axis.scatter(x, y, color=sky_blue, s=100)
factors = [(-1, -1), (1, 1)]
for xi, yi, label, (fx, fy) in zip(x, y, labels, factors):
    axis.text(
        xi + 0.08 * fx, yi + 0.08 * fy, label, fontsize=21, ha="center", va="center"
    )

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=2),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=21, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")
############################################################################
axes = fig.get_axes()
for _, (axis, letter) in enumerate(zip(axes, ["A", "B", "C", "D"])):
    axis.text(
        0.1,
        1,
        letter,
        transform=axis.transAxes,
        fontsize=24,
        fontweight="bold",
        va="bottom",
        ha="right",
    )
fig.tight_layout()
bbox = mi.compute_tight_bbox(fig, pad_inches=0.1)
fig.savefig(
    saving_at + r"\fluo_configs.png",
    dpi=300,
    bbox_inches=bbox,
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
