# %%
import matplotlib.pyplot as plt

saving_at = r"C:\Users\vie43sq\data_vincent\python_output\Chapter_I\1_16_fluo_configs"

# %%
fig, ax = plt.subplots(1, 4, figsize=(16, 5))
sky_blue = "#56B4E9"
x = [0, 1, 1, 0]
y = [0, 0, 1, 1]
labels = ["F1", "F2", "F3", "F4"]

axis = ax[0]

axis.scatter(x, y, color=sky_blue, s=100)

for xi, yi, label in zip(x, y, labels):
    axis.text(xi + 0.03, yi + 0.03, label, fontsize=12)

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(1, 1 - offset),
    xytext=(1, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(1.05, 0.5, r"$r_1$", ha="left", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(1 - offset, 1),
    xytext=(0 + offset, 1),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(0.5, 1.05, r"$r_1$", ha="center", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(0, 1 - offset),
    xytext=(0, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(-0.05, 0.5, r"$r_1$", ha="right", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(0 + offset, 1 - offset),
    xytext=(1 - offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=14, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")

#############################################################################

x = [0, 1, 1]
y = [0, 0, 1]
labels = ["F1", "F2", "F3"]
axis = ax[1]

axis.scatter(x, y, color=sky_blue, s=100)

for xi, yi, label in zip(x, y, labels):
    axis.text(xi + 0.03, yi + 0.03, label, fontsize=12)
offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(1, 1 - offset),
    xytext=(1, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(1.05, 0.5, r"$r_1$", ha="left", va="center", fontsize=14)

axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=14, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")

############################################################################
x = [0, 1]
y = [0, 0]
labels = ["F1", "F2"]
axis = ax[2]
axis.scatter(x, y, color=sky_blue, s=100)

for xi, yi, label in zip(x, y, labels):
    axis.text(xi + 0.03, yi + 0.03, label, fontsize=12)

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 0),
    xytext=(0 + offset, 0),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(0.5, -0.08, r"$r_1$", ha="center", va="center", fontsize=14)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")
############################################################################
x = [0, 1]
y = [0, 1]
labels = ["F1", "F3"]
axis = ax[3]

axis.scatter(x, y, color=sky_blue, s=100)

for xi, yi, label in zip(x, y, labels):
    axis.text(xi + 0.03, yi + 0.03, label, fontsize=12)

offset = 0.1

axis.annotate(
    "",
    xy=(1 - offset, 1 - offset),
    xytext=(0 + offset, 0 + offset),
    arrowprops=dict(arrowstyle="<->", lw=1.5),
)
axis.text(
    0.5, 0.5, r"$r_2$", ha="center", va="center", fontsize=14, backgroundcolor="white"
)

axis.set_xlim(-0.2, 1.2)
axis.set_ylim(-0.2, 1.2)

axis.axis("off")
axis.set_aspect("equal", adjustable="box")
############################################################################
axes = fig.get_axes()
for _, (axis, letter) in enumerate(zip(axes, ["A", "B", "C", "D"])):
    axis.text(
        0.1,
        1,
        letter,
        transform=axis.transAxes,
        fontsize=24,
        fontweight="bold",
        va="bottom",
        ha="right",
    )

fig.savefig(
    saving_at + r"\fluo_configs.png",
    dpi=300,
    bbox_inches="tight",
    pad_inches=0.1,
)
