# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Antibunching: 4 fluorophores, different distances, no dSTORM](#toc1_)
#   - [Preparation](#toc1_1_)
#   - [Generation](#toc1_2_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Antibunching: 4 fluorophores, different distances, no dSTORM](#toc0_)

# %%
import numpy as np

import fluopy.emissions as em
import fluopy.fluorophores as fl
import fluopy.routines as rt
import fluopy.transitions as tr

# %load_ext autoreload
# %autoreload 2

saving_at = r"D:\python_output\Chapter_I\1_12_multi_f_antibunching\noDSTORM"

# %% [markdown]
# ## <a id='toc1_1_'></a>[Preparation](#toc0_)

# %%
def generate_data(distance):
    PARAMS_ADJ = {
        k: v
        for k, v in rt.PARAMS_DSTORM.items()
        if k not in ["energy_transfer_parameters", "dstorm"]
    }

    fluorophores = fl.construct_fluorophores(
        name="cy5_dna", count=4, distance=distance, shape="square"
    )
    fluorophore_system = fl.FluorophoreSystem(fluorophores=fluorophores)
    transitions = fluorophore_system.load_transitions(
        bleaching=True,
        summarize=True,
        energy_transfer=True,
        **PARAMS_ADJ,
        dstorm=False,
        energy_transfer_parameters={
            "overwrite": {"s1": [0.01, 0]},
            "exclude": ["s0", "off"],
        },
    )
    transition_set = tr.TransitionSet(transitions, fluorophore_system)
    transition_set.finalize()

    rng = np.random.default_rng(1)
    emis = em.Emissions(seed=rng, **rt.PARAMS_EMIS)
    _, _, tau = emis.tcspc(
        transition_set, number_pulses=4e9, **rt.PARAMS_PULSE, store_time_points=True
    )
    emis.event_time_series.to_frame().to_parquet(
        saving_at + rf"\event_time_series_{distance}nm.parquet"
    )
    np.save(saving_at + rf"\tau_{distance}nm.npy", tau)
    np.save(saving_at + rf"\event_time_points_{distance}nm.npy", emis.event_time_points)

# %% [markdown]
# ## <a id='toc1_2_'></a>[Generation](#toc0_)

# %%
generate_data(3)
generate_data(6)
generate_data(9)
generate_data(18)
# Out:
# The irradiance used initially for excitation rates in
#  transition_set is now assumed to be the mean irradiance of
#  pulse and no pulse duration.
# the last frame (of index 50.0) has 0.00e+00 times the pulses of other frames.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 generate_data(3)
#       2 generate_data(6)
#       3 generate_data(9)
#
# Cell In[2], line 28, in generate_data(distance)
#      26 rng = np.random.default_rng(1)
#      27 emis = em.Emissions(seed=rng, **rt.PARAMS_EMIS)
# ---> 28 _, _, tau = emis.tcspc(
#      29     transition_set, number_pulses=4e9, **rt.PARAMS_PULSE, store_time_points=True
#      30 )
#      31 emis.event_time_series.to_frame().to_parquet(
#      32     saving_at + rf"\event_time_series_{distance}nm.parquet"
#      33 )
#      34 np.save(saving_at + rf"\tau_{distance}nm.npy", tau)
#
# File ~\data_vincent\GitHub\Photoswitching\src\fluopy\emissions.py:277, in Emissions.tcspc(self, transition_set, number_pulses, pulse_duration, time_between_pulses, excitation_rates, size, store_time_points, details)
#     275 else:
#     276     func = simulate_TCSPC
# --> 277 return_values = func(
#     278     transition_set=transition_set,
#     279     emitting_transition_ids=emitting_transition_ids,
#     280     et_transition_ids=et_transition_ids,
#     281     number_pulses=number_pulses,
#     282     pulse_duration=pulse_duration,
#     283     time_between_pulses=time_between_pulses,
#     284     excitation_rates=excitation_rates,
#     285     frame_time=self.parameters["frame_time"],
#     286     size=size,
#     287     store_time_points=store_time_points,
#     288     seed=self.parameters["seed"],
#     289 )
#     290 self.event_time_series = return_values[0]
#     291 self.event_time_points = return_values[1]
#
# File ~\data_vincent\GitHub\Photoswitching\src\fluopy\simulation_tcspc.py:297, in simulate_TCSPC(transition_set, emitting_transition_ids, et_transition_ids, number_pulses, pulse_duration, time_between_pulses, excitation_rates, frame_time, size, store_time_points, seed)
#     295 current_state_index = df[df["final_state"] == tuple(current_states)].index[0]
#     296 while time < next_pulse_time:
# --> 297     if not skip:
#     298         k += 1
#     299         if k == m * size:
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\frame.py:4098, in DataFrame.__getitem__(self, key)
#    4096 # Do we have a (boolean) 1d indexer?
#    4097 if com.is_bool_indexer(key):
# -> 4098     return self._getitem_bool_array(key)
#    4100 # We are left with two options: a single key, and a collection of keys,
#    4101 # We interpret tuples as collections only for non-MultiIndex
#    4102 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\frame.py:4160, in DataFrame._getitem_bool_array(self, key)
#    4157     return self.copy(deep=None)
#    4159 indexer = key.nonzero()[0]
# -> 4160 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\generic.py:4172, in NDFrame._take_with_is_copy(self, indices, axis)
#    4161 @final
#    4162 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4163     """
#    4164     Internal version of the `take` method that sets the `_is_copy`
#    4165     attribute to keep track of the parent dataframe (using in indexing
#    (...)   4170     See the docstring of `take` for full explanation of the parameters.
#    4171     """
# -> 4172     result = self.take(indices=indices, axis=axis)
#    4173     # Maybe set copy if we didn't actually change the index.
#    4174     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\generic.py:4152, in NDFrame.take(self, indices, axis, **kwargs)
#    4147     # We can get here with a slice via DataFrame.__getitem__
#    4148     indices = np.arange(
#    4149         indices.start, indices.stop, indices.step, dtype=np.intp
#    4150     )
# -> 4152 new_data = self._mgr.take(
#    4153     indices,
#    4154     axis=self._get_block_manager_axis(axis),
#    4155     verify=True,
#    4156 )
#    4157 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4158     self, method="take"
#    4159 )
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1373, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1370     allow_fill = True
#    1372 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1373 new_values = algos.take_nd(
#    1374     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1375 )
#    1377 # Called from three places in managers, all of which satisfy
#    1378 #  these assertions
#    1379 if isinstance(self, ExtensionBlock):
#    1380     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1381     #  algos.take_nd call above.
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\vie43sq\data_vincent\GitHub\Photoswitching\.venv\Lib\site-packages\pandas\core\array_algos\take.py:162, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
# --> 162 func(arr, indexer, out, fill_value)
#     164 if flip_order:
#     165     out = out.T
#
# KeyboardInterrupt:
