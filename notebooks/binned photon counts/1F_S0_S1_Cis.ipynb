# %%
user = r"\vie43sq"
import sys
sys.path.append(rf"C:\Users{user}\OneDrive - Universität Würzburg\GitHub\Photoswitching")

import numpy as np
import src.fluorophore_systems as fs
import src.figures as fi

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Binned photon counts
# Intensity distributions based on different photon count bin sizes

# %% [markdown]
# ### 1 fluorophore, S0 S1 Cis system

# %%
rate_dict = dict(k_tS0_tS1=[2.7e6, "excitation"],
                 k_tS1_tS0=[1e9, "fluorescent emission"],
                 k_tS1_cS0=[1e6, "isomerization"],
                 k_cS0_cS1=[1e15, "excitation cis"],
                 k_cS1_cS0=[1e9, "deexcitation cis"],
                 k_cS1_tS0=[1e6, "backisomerization"])

# %%
system = fs.Cy5(number=1,  distances=1, rates=rate_dict)

# %%
system.simulate(n_steps=10000000, seed=99, base="py")

# %%
system.process()

# %% [markdown]
# ## 0.001 ms

# %%
system.emitters(unit="s", resample="0.001ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=30)

# %% [markdown]
# ## 0.01 ms

# %%
system.emitters(unit="s", resample="0.01ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=28)

# %% [markdown]
# ## 0.1 ms

# %%
system.emitters(unit="s", resample="0.1ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=20)

# %% [markdown]
# ## 1 ms

# %%
system.emitters(unit="s", resample="1ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=30)

# %% [markdown]
# ## 10 ms

# %%
system.emitters(unit="s", resample="10ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=30)

# %% [markdown]
# ## 100 ms

# %%
system.emitters(unit="s", resample="100ms", photon_collection=1)

# %%
fig, ax = fi.FigureCollection(system).emission_events(time_series=False, bins=20)
