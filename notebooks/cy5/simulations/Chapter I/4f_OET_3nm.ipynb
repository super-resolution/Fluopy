# %%
import os
import sys

path = os.path.abspath("")
splitted = path.split(os.sep)
user_independent = os.path.join(
    splitted[0] + os.sep, splitted[1], splitted[2], splitted[3]
)
src_path = os.path.join(user_independent, "GitHub", "Photoswitching")
sys.path.append(src_path)

import src.blinking as bl
import src.distributions as dist
import src.emissions as em
import src.fcs as fcs_p
import src.figure as fi
import src.fluorophores as fl
import src.formulas as fo
import src.miscellaneous as mi
import src.network as net
import src.simulation as si
import src.prediction as pr
import src.analysis as an
import src.transitions as tr

import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

import warnings


def custom_warning_format(msg, category, filename, lineno, line=None):
    if line is None:
        import linecache

        line = linecache.getline(filename, lineno)
    return f"WARNING for line: {line} {msg} \n"


warnings.formatwarning = custom_warning_format

# %%
fluorophores = fl.construct_fluorophores(
    name="cy5_dna", distance=3, count=3, shape="square"
)
fluorophore_system = fl.FluorophoreSystem(fluorophores=fluorophores)

irradiance=5
wavelength=640
bleaching=True
energy_transfer=True
reducing_agent="mea"
concentration=100
ph=7.5

# %%
transitions = fluorophore_system.load_transitions(
    irradiance=irradiance,
    wavelength=wavelength,
    bleaching=bleaching,
    energy_transfer=energy_transfer,
    dstorm=True,
    dstorm_parameters={'reducing_agent':reducing_agent,
    'concentration':concentration,
    'ph':ph},
)
transition_set = tr.TransitionSet(transitions, fluorophore_system)
#transition_set = transition_set.adjust_rates({5:2e4, 4:1e7)
transition_set.finalize()

# %%
transition_set.transition_df
# Out:
#                                                                      transition_type  \
# Fluorophore                         identity
# cy5_dna                             0                      TransitionType.EXCITATION
#                                     1            TransitionType.FLUORESCENT_EMISSION
#                                     2         TransitionType.INTERSYSTEM_CROSSING_ST
#                                     3         TransitionType.INTERSYSTEM_CROSSING_TS
#                                     4                   TransitionType.ISOMERIZATION
#                                     5                      TransitionType.PHOTO_BISO
#                                     6                      TransitionType.THERM_BISO
#                                     7           TransitionType.INTERNAL_CONVERSION_S
#                                     8                      TransitionType.ET_CYCLE_T
#                                     9                      TransitionType.ET_CYCLE_S
#                                     10                    TransitionType.REDUCTION_T
#                                     11                    TransitionType.REDUCTION_S
#                                     12                    TransitionType.OXIDATION_1
#                                     13               TransitionType.PHOTOBLEACHING_1
# D: cy5_dna, A: cy5_dna, dist: 3.0   14                     TransitionType.CIS_FRET_1
#                                     15                     TransitionType.CIS_FRET_2
#                                     16                     TransitionType.OFF_FRET_1
#                                     17                     TransitionType.OFF_FRET_2
#                                     18                           TransitionType.FRET
#                                     19               TransitionType.S_S_ANNIHILATION
#                                     20               TransitionType.S_T_ANNIHILATION
# D: cy5_dna, A: cy5_dna, dist: 4.243 21                     TransitionType.CIS_FRET_1
#                                     22                     TransitionType.CIS_FRET_2
#                                     23                     TransitionType.OFF_FRET_1
#                                     24                     TransitionType.OFF_FRET_2
#                                     25                           TransitionType.FRET
#                                     26               TransitionType.S_S_ANNIHILATION
#                                     27               TransitionType.S_T_ANNIHILATION
#
#                                              abbreviation  \
# Fluorophore                         identity
# cy5_dna                             0                 EXC
#                                     1                 FLU
#                                     2               ISCST
#                                     3               ISCTS
#                                     4                 ISO
#                                     5               PBISO
#                                     6               TBISO
#                                     7                 ICS
#                                     8                 ETT
#                                     9                 ETS
#                                     10               REDT
#                                     11               REDS
#                                     12               OXI1
#                                     13               BLE1
# D: cy5_dna, A: cy5_dna, dist: 3.0   14             CFRET1
#                                     15             CFRET2
#                                     16             OFRET1
#                                     17             OFRET2
#                                     18               FRET
#                                     19                SSA
#                                     20                STA
# D: cy5_dna, A: cy5_dna, dist: 4.243 21             CFRET1
#                                     22             CFRET2
#                                     23             OFRET1
#                                     24             OFRET2
#                                     25               FRET
#                                     26                SSA
#                                     27                STA
#
#                                                     initial_state  \
# Fluorophore                         identity
# cy5_dna                             0              SingleState.S0
#                                     1              SingleState.S1
#                                     2              SingleState.S1
#                                     3              SingleState.T1
#                                     4              SingleState.S1
#                                     5             SingleState.Cis
#                                     6             SingleState.Cis
#                                     7              SingleState.S1
#                                     8              SingleState.T1
#                                     9              SingleState.S1
#                                     10             SingleState.T1
#                                     11             SingleState.S1
#                                     12           SingleState.OFF1
#                                     13             SingleState.T1
# D: cy5_dna, A: cy5_dna, dist: 3.0   14         PairedState.S1_Cis
#                                     15         PairedState.S1_Cis
#                                     16        PairedState.S1_OFF1
#                                     17        PairedState.S1_OFF1
#                                     18          PairedState.S1_S0
#                                     19          PairedState.S1_S1
#                                     20          PairedState.S1_T1
# D: cy5_dna, A: cy5_dna, dist: 4.243 21         PairedState.S1_Cis
#                                     22         PairedState.S1_Cis
#                                     23        PairedState.S1_OFF1
#                                     24        PairedState.S1_OFF1
#                                     25          PairedState.S1_S0
#                                     26          PairedState.S1_S1
#                                     27          PairedState.S1_T1
#
#                                                       final_state  \
# Fluorophore                         identity
# cy5_dna                             0              SingleState.S1
#                                     1              SingleState.S0
#                                     2              SingleState.T1
#                                     3              SingleState.S0
#                                     4             SingleState.Cis
#                                     5              SingleState.S0
#                                     6              SingleState.S0
#                                     7              SingleState.S0
#                                     8              SingleState.S0
#                                     9              SingleState.S0
#                                     10           SingleState.OFF1
#                                     11           SingleState.OFF1
#                                     12             SingleState.S0
#                                     13              SingleState.B
# D: cy5_dna, A: cy5_dna, dist: 3.0   14         PairedState.S0_Cis
#                                     15          PairedState.S0_S0
#                                     16          PairedState.S0_S0
#                                     17        PairedState.S0_OFF1
#                                     18          PairedState.S0_S1
#                                     19          PairedState.S0_S1
#                                     20          PairedState.S0_T1
# D: cy5_dna, A: cy5_dna, dist: 4.243 21         PairedState.S0_Cis
#                                     22          PairedState.S0_S0
#                                     23          PairedState.S0_S0
#                                     24        PairedState.S0_OFF1
#                                     25          PairedState.S0_S1
#                                     26          PairedState.S0_S1
#                                     27          PairedState.S0_T1
#
#                                                       rate  photon  \
# Fluorophore                         identity
# cy5_dna                             0         1.453925e+07   False
#                                     1         1.588235e+08    True
#                                     2         8.300000e+05   False
#                                     3         5.000000e+03   False
#                                     4         4.000000e+06   False
#                                     5         9.665504e+04   False
#                                     6         5.000000e+03   False
#                                     7         4.245818e+08   False
#                                     8         3.065343e+05   False
#                                     9         3.065343e+06   False
#                                     10        3.065343e+02   False
#                                     11        3.065343e+03   False
#                                     12        2.000000e-02   False
#                                     13        1.000000e+01   False
# D: cy5_dna, A: cy5_dna, dist: 3.0   14        1.189412e+11   False
#                                     15        3.678593e+09   False
#                                     16        3.833262e+06   False
#                                     17        3.829429e+09   False
#                                     18        6.398774e+10   False
#                                     19        1.226198e+11   False
#                                     20        3.614255e+10   False
# D: cy5_dna, A: cy5_dna, dist: 4.243 21        1.486009e+10   False
#                                     22        4.595905e+08   False
#                                     23        4.789144e+05   False
#                                     24        4.784355e+08   False
#                                     25        7.994404e+09   False
#                                     26        1.531968e+10   False
#                                     27        4.515524e+09   False
#
#                                                                fluorophore_ids  \
# Fluorophore                         identity
# cy5_dna                             0                                [0, 1, 2]
#                                     1                                [0, 1, 2]
#                                     2                                [0, 1, 2]
#                                     3                                [0, 1, 2]
#                                     4                                [0, 1, 2]
#                                     5                                [0, 1, 2]
#                                     6                                [0, 1, 2]
#                                     7                                [0, 1, 2]
#                                     8                                [0, 1, 2]
#                                     9                                [0, 1, 2]
#                                     10                               [0, 1, 2]
#                                     11                               [0, 1, 2]
#                                     12                               [0, 1, 2]
#                                     13                               [0, 1, 2]
# D: cy5_dna, A: cy5_dna, dist: 3.0   14        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     15        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     16        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     17        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     18        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     19        [(0, 1), (0, 2), (1, 0), (2, 0)]
#                                     20        [(0, 1), (0, 2), (1, 0), (2, 0)]
# D: cy5_dna, A: cy5_dna, dist: 4.243 21                        [(1, 2), (2, 1)]
#                                     22                        [(1, 2), (2, 1)]
#                                     23                        [(1, 2), (2, 1)]
#                                     24                        [(1, 2), (2, 1)]
#                                     25                        [(1, 2), (2, 1)]
#                                     26                        [(1, 2), (2, 1)]
#                                     27                        [(1, 2), (2, 1)]
#
#                                               absorbing
# Fluorophore                         identity
# cy5_dna                             0             False
#                                     1             False
#                                     2             False
#                                     3             False
#                                     4             False
#                                     5             False
#                                     6             False
#                                     7             False
#                                     8             False
#                                     9             False
#                                     10            False
#                                     11            False
#                                     12            False
#                                     13             True
# D: cy5_dna, A: cy5_dna, dist: 3.0   14            False
#                                     15            False
#                                     16            False
#                                     17            False
#                                     18            False
#                                     19            False
#                                     20            False
# D: cy5_dna, A: cy5_dna, dist: 4.243 21            False
#                                     22            False
#                                     23            False
#                                     24            False
#                                     25            False
#                                     26            False
#                                     27            False

# %%
import sim_data_analysis as sda

# %%
memory = 0
threshold = 10
number_of_simulations = 1

# %%
sda.simulate_data(number_of_simulations=number_of_simulations, memory=memory, 
                  threshold=threshold, transition_set=transition_set,
                  long_sim=False, memmap=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sda.simulate_data(number_of_simulations=number_of_simulations, memory=memory,
#       2                   threshold=threshold, transition_set=transition_set,
#       3                   long_sim=False, memmap=True)
#
# File c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\notebooks\cy5\simulations\Chapter I\sim_data_analysis.py:55, in simulate_data(number_of_simulations, memory, threshold, transition_set, long_sim, memmap)
#      53     memmap_path = memmap
#      54 elif memmap:
# ---> 55     memmap_path = ''
#      56 else:
#      57     memmap_path = None
#
# File c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\src\simulation.py:101, in run(self, start_at, size, end_time, seed, use_memmap)
#      92 if end_time is None:
#      93     self.time_series, self.transition_series = direct_method_steps(
#      94         transition_matrix=self.transition_set.transition_matrix,
#      95         row_sums=self.transition_set.row_sums,
#    (...)
#      99         use_memmap=use_memmap,
#     100     )
# --> 101 else:
#     102     self.time_series, self.transition_series = direct_method_time(
#     103         transition_matrix=self.transition_set.transition_matrix,
#     104         row_sums=self.transition_set.row_sums,
#    (...)
#     109         use_memmap=use_memmap,
#     110     )
#     112 final_states = self.transition_set.combined_state_transitions_df["final_state"]
#
# File c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\src\simulation.py:434, in direct_method_time(transition_matrix, row_sums, start_index, size, end_time, seed, use_memmap)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\Users\vie43sq\Miniconda3\envs\markovmodels\Lib\site-packages\numpy\core\fromnumeric.py:1400, in searchsorted(a, v, side, sorter)
#    1332 @array_function_dispatch(_searchsorted_dispatcher)
#    1333 def searchsorted(a, v, side='left', sorter=None):
#    1334     """
#    1335     Find indices where elements should be inserted to maintain order.
#    1336
#    (...)
#    1398
#    1399     """
# -> 1400     return _wrapfunc(a, 'searchsorted', v, side=side, sorter=sorter)
#
# File c:\Users\vie43sq\Miniconda3\envs\markovmodels\Lib\site-packages\numpy\core\fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Photoswitching fingerprint

# %%
rng = np.random.default_rng(1)

# %%
num_simulations = 300
all_events_summed = pd.Series(np.zeros(300001), np.linspace(0, 300, 300001))
transition_set.finalize()

for i in range(num_simulations):
    simulation = si.Simulation(transition_set)
    simulation.run(size=1e6, seed=rng, end_time=300)
    emis = em.Emissions(frame_time='1ms', bandpass=[665, 731], seed=rng)
    emis.extract(simulation)
    photon_collection_rate = fo.calculate_photon_collection_rate(NA=1.45, n1=1.51)
    emis.add_photon_collection_objective(p=photon_collection_rate, seed=rng) 
    emis.add_transmittance(p=0.9, seed=rng)  # mirror 90/100
    emis.add_transmittance(p=0.99, seed=rng) # lens 1
    emis.add_transmittance(p=0.99, seed=rng) # lens 2
    emis.add_quantum_efficiency(p=0.85, seed=rng)
    emis.add_poisson_noise(rate=0.6, seed=rng)
    emis.apply_threshold(threshold=10)
    all_events_summed = all_events_summed + emis.event_time_series.values

# %%
ax = fi.universal_figure(data=[all_events_summed.index[300:], rel_all_events_discard_bl_1e1], 
                        label='1e1')
fi.universal_figure(data=[all_events_summed.index[300:], rel_all_events_discard_bl_1e3],
                    axes=ax[0], color='g', label='1e3')
fi.universal_figure(data=[all_events_summed.index[300:], rel_all_events_discard_bl_1e4],
                    axes=ax[0], color='y', label='1e4')
fi.universal_figure(data=[all_events_summed.index[300:], rel_all_events_discard_bl_1e2], 
                    title='bleaching rate', ylabel='% emission', xlabel='time (s)', 
                    axes=ax[0], color='r', label='1e2', legend=True)
fig = mi.get_figure(ax)
fig.savefig("bl_rate_cum_locs.svg")
