# %% [markdown]
# # Markov chain represented by a finite state-machine

# %% [markdown]
# ## Biological/physical context

# %% [markdown]
# ### Jablonski diagram

# %% [markdown]
# ![Jablonski diagram](.\images\Jablonski_diagram.png)

# %% [markdown]
# ### Jablonski diagram dSTORM

# %% [markdown]
# ![Jablonski diagram dSTORM](.\images\Jablonski_diagram_dSTORM.png)

# %% [markdown]
# Possible states:
#
# S0 - singlet ground state\
# S1 - singlet first electronic state\
# T1 - triplet state, phosphorescent\
# R (reduced) - non-emitting (dark), radical state\
# B (bleached) - an irreversible, non-emitting state
