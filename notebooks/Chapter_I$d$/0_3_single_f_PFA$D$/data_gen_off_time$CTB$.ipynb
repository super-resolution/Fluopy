# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Photoswitching fingerprints: modulating OFF time](#toc1_)
#   - [Data generation](#toc1_1_)
#     - [OFF to ON rate: $5*10^{-2}$](#toc1_1_1_)
#     - [OFF to ON rate: $5*10^{-1}$](#toc1_1_2_)
#     - [OFF to ON rate: $5*10^{0}$](#toc1_1_3_)
#     - [OFF to ON rate: $5*10^{1}$](#toc1_1_4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Photoswitching fingerprints: modulating OFF time](#toc0_)

# %%
import numpy as np

import fluopy.distributions as dist
import fluopy.figure as fi
import fluopy.fluorophores as fl
import fluopy.transitions as tr
import fluopy.routines as rt

# %load_ext autoreload
# %autoreload 2

import warnings


def custom_warning_format(msg, category, filename, lineno, line=None):
    if line is None:
        import linecache

        line = linecache.getline(filename, lineno)
    if "Floating point precision" in str(msg):
        return ""
    return f"WARNING for line: {line} {msg} \n"


warnings.formatwarning = custom_warning_format

saving_at = r"D:\python_output\Chapter_I\0_3_single_f_PFA\off_time"
# Out:
# fluopy.distributions version: 0.1.0
# fluopy.figure version: 0.1.0
# fluopy.fluorophores version: 0.1.0
# fluopy.transitions version: 0.1.0
# fluopy.routines version: 0.1.0

# %% [markdown]
# ## <a id='toc1_1_'></a>[Data generation](#toc0_)

# %%
fluorophores = fl.construct_fluorophores(name="cy5_dna", count=1)
fluorophore_system = fl.FluorophoreSystem(fluorophores=fluorophores)
transitions = fluorophore_system.load_transitions(
    bleaching=True,
    **rt.PARAMS_DSTORM,
    summarize=True,
)
transition_set = tr.TransitionSet(transitions, fluorophore_system)
transition_set.finalize()

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[OFF to ON rate: $5*10^{-2}$](#toc0_)

# %%
rng = np.random.default_rng(1)
transition_set = transition_set.adjust_rates({12: 5e-2})
transition_set.finalize()
_, _, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=500,
    filepath=saving_at + r"\5e-2",
    filename="off_on_5e-2",
    seed=rng,
    use_memmap=r"C:\Users\vie43sq\Desktop\Simulations\memmaps\run_3",
)

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[OFF to ON rate: $5*10^{-1}$](#toc0_)

# %%
rng = np.random.default_rng(2)
transition_set = transition_set.adjust_rates({12: 5e-1})
transition_set.finalize()
_, _, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=500,
    filepath=saving_at + r"\5e-1",
    filename="off_on_5e-1",
    seed=rng,
    use_memmap=r"C:\Users\vie43sq\Desktop\Simulations\memmaps\run_3",
)

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[OFF to ON rate: $5*10^{0}$](#toc0_)

# %%
rng = np.random.default_rng(3)
transition_set = transition_set.adjust_rates({12: 5e0})
transition_set.finalize()
_, _, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=300,
    filepath=saving_at + r"\5e0",
    filename="off_on_5e0",
    seed=rng,
    use_memmap=r"C:\Users\vie43sq\Desktop\Simulations\memmaps\run_3",
)

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[OFF to ON rate: $5*10^{1}$](#toc0_)

# %%
rng = np.random.default_rng(4)
transition_set = transition_set.adjust_rates({12: 5e1})
transition_set.finalize()
_, _, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=300,
    filepath=saving_at + r"\5e1",
    filename="off_on_5e1",
    seed=rng,
    use_memmap=r"C:\Users\vie43sq\Desktop\Simulations\memmaps\run_3",
)
