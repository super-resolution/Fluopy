# %%
import numpy as np
import pandas as pd
import locan as lc
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

import os
import sys
path = os.path.abspath("")
splitted = path.split(os.sep)
user_independent = os.path.join(splitted[0]+os.sep, splitted[1], splitted[2], splitted[3])
src_path = os.path.join(user_independent, 'GitHub', 'Photoswitching')
sys.path.append(src_path)

import src.miscellaneous as mi
import src.figure as fi
import src.blinking as bl
import src.emissions as em
import exp_data_analysis as eda

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = r'C:\Users\vie43sq\Desktop\origami\Reference_1xCy5-Origami_TimeTrace'

# %%
memory = 0
threshold = 0

# %%
eda.go_through_files(path=path, memory=memory, threshold=threshold, skip_id=[4,7,8,9])

# %%
eda.sum_all_files(path=path, memory=memory, threshold=threshold,
                     skip_id=[4,7,8,9])
# Out:
# c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\src\figure.py:194: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)

# %%
memory = 0
threshold = 10

# %%
eda.go_through_files(path=path, memory=memory, threshold=threshold, skip_id=[4,7,8,9])

# %%
eda.sum_all_files(path=path, memory=memory, threshold=threshold,
                     skip_id=[4,7,8,9])
# Out:
# c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\src\figure.py:194: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)

# %%
memory = 30
threshold = 10

# %%
eda.go_through_files(path=path, memory=memory, threshold=threshold,
                     skip_id=[4,7,8,9])

# %%
eda.sum_all_files(path=path, memory=memory, threshold=threshold,
                     skip_id=[4,7,8,9])
# Out:
# c:\Users\vie43sq\OneDrive - Universität Würzburg\GitHub\Photoswitching\src\figure.py:194: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_yscale(yscale)
