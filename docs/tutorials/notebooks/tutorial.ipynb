# %% [markdown]
# # Tutorial about fluopy

# %% [markdown]
# Here we outline the principle use of fluopy.

# %%
from pathlib import Path

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import fluopy

# %%
fluopy.__version__
# Out:
# '0.1.0.dev134+ga4dbc28.d20250628'

# %%
dir(fluopy)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_version',
#  'analysis',
#  'blinking',
#  'distributions',
#  'emissions',
#  'fcs',
#  'figure',
#  'fitting',
#  'fluo_data',
#  'fluorophores',
#  'formulas',
#  'miscellaneous',
#  'network',
#  'prediction',
#  'routines',
#  'simulation',
#  'simulation_tcspc',
#  'transitions']
