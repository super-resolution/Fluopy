# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Photoswitching fingerprints: modulating bleaching rate](#toc1_)
#   - [Data generation](#toc1_1_)
#     - [Bleaching rate: $10^{1}$](#toc1_1_1_)
#     - [Bleaching rate: $10^{2}$](#toc1_1_2_)
#     - [Bleaching rate: $10^{3}$](#toc1_1_3_)
#     - [Bleaching rate: $10^{4}$](#toc1_1_4_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Photoswitching fingerprints: modulating bleaching rate](#toc0_)

# %%
import numpy as np

import fluopy.distributions as dist
import fluopy.figure as fi
import fluopy.fluorophores as fl
import fluopy.transitions as tr
import fluopy.routines as rt

# %load_ext autoreload
# %autoreload 2

import warnings


def custom_warning_format(msg, category, filename, lineno, line=None):
    if line is None:
        import linecache

        line = linecache.getline(filename, lineno)
    return f"WARNING for line: {line} {msg} \n"


warnings.formatwarning = custom_warning_format

for package in [dist, fi, fl, tr, rt]:
    print(f"{package.__name__} version: {package.__version__}")

saving_at = r"D:\python_output\Chapter_I\0_3_single_f_PFA\bl_rate"
# Out:
# fluopy.distributions version: 0.1.0
# fluopy.figure version: 0.1.0
# fluopy.fluorophores version: 0.1.0
# fluopy.transitions version: 0.1.0
# fluopy.routines version: 0.1.0

# %% [markdown]
# ## <a id='toc1_1_'></a>[Data generation](#toc0_)

# %%
fluorophores = fl.construct_fluorophores(name="cy5_dna", count=1)
fluorophore_system = fl.FluorophoreSystem(fluorophores=fluorophores)
transitions = fluorophore_system.load_transitions(
    bleaching=True,
    **rt.PARAMS_DSTORM,
)
transition_set = tr.TransitionSet(transitions, fluorophore_system)
transition_set = transition_set.adjust_rates({5: 2e4, 4: 1e7})
transition_set.finalize()
rng = np.random.default_rng(1)

# %% [markdown]
# ### <a id='toc1_1_1_'></a>[Bleaching rate: $10^{1}$](#toc0_)

# %%
transition_set = transition_set.adjust_rates({13: 1e1})
transition_set.finalize()
fingerprint_1e1, bl_times_1e1, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=500,
    filepath=saving_at + r"\1e1",
    filename="bl_rate_1e1",
    seed=rng,
)

# %% [markdown]
# ### <a id='toc1_1_2_'></a>[Bleaching rate: $10^{2}$](#toc0_)

# %%
transition_set = transition_set.adjust_rates({13: 1e2})
transition_set.finalize()
fingerprint_1e2, bl_times_1e2, _ = rt.fingerprint_analysis(
    transition_set,
    batches=1,
    batch_size=500,
    filepath=saving_at + r"\1e2",
    filename="bl_rate_1e2",
    seed=rng,
)

# %% [markdown]
# ### <a id='toc1_1_3_'></a>[Bleaching rate: $10^{3}$](#toc0_)

# %%
transition_set = transition_set.adjust_rates({13: 1e3})
transition_set.finalize()
fingerprint_1e3, bl_times_1e3, _ = rt.fingerprint_analysis(
    transition_set,
    batches=3,
    batch_size=500,
    filepath=saving_at + r"\1e3",
    filename="bl_rate_1e3",
    seed=rng,
)

# %% [markdown]
# ### <a id='toc1_1_4_'></a>[Bleaching rate: $10^{4}$](#toc0_)

# %%
transition_set = transition_set.adjust_rates({13: 1e4})
transition_set.finalize()
fingerprint_1e4, bl_times_1e4, _ = rt.fingerprint_analysis(
    transition_set,
    batches=30,
    batch_size=500,
    filepath=saving_at + r"\1e4",
    filename="bl_rate_1e4",
    seed=rng,
)
